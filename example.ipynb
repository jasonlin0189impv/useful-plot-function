# %%
import pandas as pd
from src.methods import BasicPlot

# %%
result = pd.read_csv('example_data.csv')

# %%
basic_plot = BasicPlot(df=result)

# %%
basic_plot.plot_boxplot(data_col='survival_time', label_col='label', figsize=(4, 5))

# %%
basic_plot.plot_distribution(data_col='survival_time', label_col='label', figsize=(8, 4))

# %%
basic_plot.plot_cluster_barplot(data_col='log_score', label_col='label', figsize=(8, 4))

# or you can given user defined binned name
basic_plot.plot_cluster_barplot(data_col='log_score', label_col='label', figsize=(8, 4), binned_label=[r'$-\infty$ ~ -34411', r'-34411 ~ -6607', r'-6607 ~ -404', r'-404 ~ 0'])

# %%
basic_plot.plot_stack_barplot(data_col='have_services', label_col='label', figsize=(8, 4))
